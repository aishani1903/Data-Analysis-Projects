# %% [markdown]
# <a href="https://colab.research.google.com/github/aishani1903/Data-Analysis-Projects/blob/main/StudentHourScore_Simple_Linear_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv('StudentHoursScores.csv')
ds
# Out:
#     Hours  Scores
# 0     7.7      79
# 1     5.9      60
# 2     4.5      45
# 3     3.3      33
# 4     1.1      12
# 5     8.9      87
# 6     2.5      21
# 7     1.9      19
# 8     2.7      29
# 9     8.3      81
# 10    5.5      58
# 11    9.2      88
# 12    1.5      14
# 13    3.5      34
# 14    8.5      85
# 15    3.2      32
# 16    6.5      66
# 17    2.5      21
# 18    9.6      96
# 19    4.3      42
# 20    4.1      40
# 21    3.0      30
# 22    2.6      25

# %%
ds.describe()
# Out:
#            Hours     Scores
# count  23.000000  23.000000
# mean    4.817391  47.695652
# std     2.709688  27.103228
# min     1.100000  12.000000
# 25%     2.650000  27.000000
# 50%     4.100000  40.000000
# 75%     7.100000  72.500000
# max     9.600000  96.000000

# %%
ds.head()
# Out:
#    Hours  Scores
# 0    7.7      79
# 1    5.9      60
# 2    4.5      45
# 3    3.3      33
# 4    1.1      12

# %%
ds.shape
# Out:
# (23, 2)

# %%
ds.columns
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
print(type(ds))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
ds.values
# Out:
# array([[ 7.7, 79. ],
#        [ 5.9, 60. ],
#        [ 4.5, 45. ],
#        [ 3.3, 33. ],
#        [ 1.1, 12. ],
#        [ 8.9, 87. ],
#        [ 2.5, 21. ],
#        [ 1.9, 19. ],
#        [ 2.7, 29. ],
#        [ 8.3, 81. ],
#        [ 5.5, 58. ],
#        [ 9.2, 88. ],
#        [ 1.5, 14. ],
#        [ 3.5, 34. ],
#        [ 8.5, 85. ],
#        [ 3.2, 32. ],
#        [ 6.5, 66. ],
#        [ 2.5, 21. ],
#        [ 9.6, 96. ],
#        [ 4.3, 42. ],
#        [ 4.1, 40. ],
#        [ 3. , 30. ],
#        [ 2.6, 25. ]])

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   23 non-null     float64
#  1   Scores  23 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 496.0 bytes

# %%
ds.describe()
# Out:
#            Hours     Scores
# count  23.000000  23.000000
# mean    4.817391  47.695652
# std     2.709688  27.103228
# min     1.100000  12.000000
# 25%     2.650000  27.000000
# 50%     4.100000  40.000000
# 75%     7.100000  72.500000
# max     9.600000  96.000000

# %%
ds.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.997656
# Scores  0.997656  1.000000

# %%
ds.nunique()
# Out:
# Hours     22
# Scores    22
# dtype: int64

# %% [markdown]
# Visualization in matplotlib

# %%
x = ds['Hours']
y = ds ['Scores']
plt.scatter(x, y, marker = '+', color = 'green')
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Student Hours Scores")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = ds['Hours']
y = ds ['Scores']
plt.plot(x, y, label = 'a', marker = '+', color = 'green')
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.legend()
plt.show()

# %%
x = ds['Hours']
y = ds ['Scores']
plt.bar(x, y, label = 'a', width = .1, color = 'red')
# Out:
# <BarContainer object of 23 artists>

# %% [markdown]
# Splitting of data into training and testing data

# %%
x = ds.iloc[:,:-1].values
y = ds.iloc[:,1].values
print(x)
print(y)
# Out:
# [[7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [2.7]
#  [8.3]
#  [5.5]
#  [9.2]
#  [1.5]
#  [3.5]
#  [8.5]
#  [3.2]
#  [6.5]
#  [2.5]
#  [9.6]
#  [4.3]
#  [4.1]
#  [3. ]
#  [2.6]]
# [79 60 45 33 12 87 21 19 29 81 58 88 14 34 85 32 66 21 96 42 40 30 25]

# %%
import sklearn
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size = 1/3, random_state = 1)

# %% [markdown]
# Creating simple linear model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Prediction

# %%
ypredict = model.predict(xtest)
ypredict
# Out:
# array([40.50038393, 24.63061172, 32.56549782, 34.54921935, 42.48410545,
#        64.30504223, 54.3864346 , 10.74456104])

# %%
ytest
# Out:
# array([40, 21, 33, 34, 42, 66, 58, 12])

# %%
model.predict([[6]])
# Out:
# array([59.34573842])

# %%
model.coef_
# Out:
# array([9.91860763])

# %%
model.intercept_
# Out:
# -0.16590734578961275

# %%
9.9186 * 6 + (-0.1659)    #Proved :)
# Out:
# 59.3457

# %% [markdown]
# Visualize

# %%
plt.scatter(xtrain, ytrain, color = 'r')
plt.plot(xtrain,model.predict(xtrain))
plt.show()

# %%
plt.scatter(xtest,ytest,color='r')
plt.plot(xtrain,model.predict(xtrain))
plt.show()
